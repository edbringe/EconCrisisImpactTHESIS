# %%
import pandas as pd #Must be using an older version of Pandas due to compatability issues with the anomaly detectors
import matplotlib.pyplot as plt
import numpy as np

# %%
D_imp_reg = pd.read_csv('summary\D_imp_reg.csv',sep='\t',index_col=[0])
# Out:
#      system  region  Artificial Surfaces  As - combustion - air  \
# year
# 1995    ixi      AT                  0.0           1.191050e+05
# 1995    ixi      BE                  0.0           1.856026e+05
# 1995    ixi      BG                  0.0           7.479482e+03
# 1995    ixi      CY                  0.0           2.970469e+04
# 1995    ixi      CZ                  0.0           3.509062e+04
# ...     ...     ...                  ...                    ...
# 2022    pxp      WM                  NaN           1.474268e+06
# 2022    pxp  global                  NaN           4.867833e+07
# 2022    pxp    EU27                  NaN           1.323196e+07
# 2022    pxp    BRIC                  NaN           6.421351e+06
# 2022    pxp      G7                  NaN           2.470976e+07
#
#       As - non combustion - Agglomeration plant - pellets - air  \
# year
# 1995                                         424.367297
# 1995                                         812.457818
# ...

# %%
D_imp = pd.read_csv('summary\D_imp.csv', sep='\t', index_col=[0])

# %%
D_imp
# Out:
#                                                     year system  region  \
# sector
# Activities auxiliary to financial intermediatio...  1995    ixi      AT
# Activities auxiliary to financial intermediatio...  1995    ixi      BE
# Activities auxiliary to financial intermediatio...  1995    ixi      BG
# Activities auxiliary to financial intermediatio...  1995    ixi      CY
# Activities auxiliary to financial intermediatio...  1995    ixi      CZ
# ...                                                  ...    ...     ...
# products of Vegetable oils and fats                 2022    pxp      WM
# products of Vegetable oils and fats                 2022    pxp  global
# products of Vegetable oils and fats                 2022    pxp    EU27
# products of Vegetable oils and fats                 2022    pxp    BRIC
# products of Vegetable oils and fats                 2022    pxp      G7
#
#                                                     Artificial Surfaces  \
# sector
# ...
